# %% [markdown]
# ![data-search.jpg](data:image/jpeg;base64,...)
# <br>
# Este é um conjunto de dados público de comércio eletrônico brasileiro de pedidos feitos na Olist Store. O conjunto de dados contém informações de 100.000 pedidos de 2016 a 2018 feitos em vários marketplaces no Brasil. Seus recursos permitem visualizar um pedido de várias dimensões: do status do pedido, preço, pagamento e desempenho do frete até a localização do cliente, atributos do produto e, finalmente, avaliações escritas pelos clientes. Há 9 arquivos csv disponíveis no Kaggle viz.

# %% [markdown]
# ## Import libs

# %%
# !pip install gcsfs #INSTALAÇÃO DA BIBLIOTECA GOOGLE CLOUD STORAGE FILE SYSTEM
from google.cloud import storage
from pymongo import MongoClient
import os
import matplotlib.pyplot as plt
import pymongo #PIP INSTALL PYMONGO[srv]
from pymongo import MongoClient 
import pandas as pd
import numpy as np
# !pip install pyspark #INSTALAÇÃO DA BIBLIOTECA PYSPARK
from pyspark.sql import SparkSession #IMPORTAR A SPARKSESSION
import pyspark.sql.functions as F 
from pyspark.sql.types import * #IMPORTAR OS TIPOS DE VARIÁVEIS DO SPARK
# !pip install mysql-connector-python
import mysql.connector
from mysql.connector import Error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.4/281.4 MB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 16.3 MB/s eta 0:00:00
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845512 sha256=cf84bc45718950940bfdec3a8f077757fcc7bd707f343288e4374ae39ef3972e
#   Stored in directory: /root/.cache/pip/wheels/43/dc/11/ec201cd671da62fa9c5cc77078235e40722170ceba231d7598
# Successfully built pyspark
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 51.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# Testando o sqlachemy

# %%
pip install sqlalchemy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
engine = sqlalchemy.create_engine('postgresql://postgres:test1234@localhost:5432/sql-shack-demo')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b9279d49cc84> in <module>
# ----> 1 engine = sqlalchemy.create_engine('postgresql://postgres:test1234@localhost:5432/sql-shack-demo')
#
# NameError: name 'sqlalchemy' is not defined

# %%
from sqlalchemy import URL

url_object = URL.create(
    "postgresql+pg8000", #
    username="dbuser",
    password="kx@jj5/g",  # 
    host="pghost10",
    database="appdb",
)

# %%
import sqlalchemy

# Create the engine to connect to the PostgreSQL database
engine = sqlalchemy.create_engine('postgresql://postgres:test1234@localhost:5432/sql-shack-demo')
 
# Read data from CSV and load into a dataframe object
data = pandas.read_csv('C:/temp/pandas-db-sqlshack-demo/pandas-env/superstore.csv')
 
# Write data into the table in PostgreSQL database
data.to_sql('superstore', engine)

# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine

engine = create_engine('mysql+mysqlconnector://[user]:[pass]@[host]:[port]/[schema]', echo=False)
data.to_sql(name='sample_table2', con=engine, if_exists = 'append', index=False)

# %%
pip install pymysql

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

user = 'root'
passw = 'C/Mor64(FKE|Qnl)'
host =  '34.132.136.180'  # either localhost or ip e.g. '172.17.0.2' or hostname address 
port = 3306 
database = 'olist-dataset-orig'

# %%
df = pd.read_csv(path1,sep=',',encoding = 'ISO-8859-1')

# %%
mydb = create_engine('mysql+pymysql://' + user + ':' + passw + '@' + host + ':' + str(port) + '/' + database , echo=False)

directory = r'gs://e-commerce-brazil/bases-originais-olist/'  # path of csv file
csvFileName = 'olist_customers_dataset.csv'

df = pd.read_csv(os.path.join(directory, csvFileName ))

df.to_sql(name=csvFileName[:-4], con=mydb, if_exists = 'replace', index=False)

"""
if_exists: {'fail', 'replace', 'append'}, default 'fail'
     fail: If table exists, do nothing.
     replace: If table exists, drop it, recreate it, and insert data.
     append: If table exists, insert data. Create if does not exist.
"""

# %% [markdown]
# Configurar ambiente de trabalho (conexão gcs)

# %% [markdown]
# # Configs acess GCS

# %% [markdown]
# Configurando chave de acesso para gcs

# %%
# Chave JSON jogando o caminho em uma váriavel
serviceAccount = '/content/it-data-search-913f6b90f4d3.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = serviceAccount

# %%
#FAZER O ACESSO A BUCKET
client = storage.Client()

#CRIAR UMA VARIÁVEL PARA RECEBER O NOME DA BUCKET

bucket = client.get_bucket('e-commerce-brazil')

#ESCOLHER O ARQUIVO DENTRO DA BUCKET --

bucket.blob('olist_customers_dataset.csv') #Path do arquivo na storage
bucket.blob('olist_geolocation_dataset.csv')
bucket.blob('olist_order_items_dataset.csv')
bucket.blob('olist_order_payments_dataset.csv')
bucket.blob('olist_order_reviews_dataset.csv')
bucket.blob('olist_orders_dataset.csv')
bucket.blob('olist_products_dataset.csv')
bucket.blob('olist_sellers_dataset.csv')
bucket.blob('product_category_name_translation.csv')


#CRIAR UMA VARIÁVEL PARA RECEBER O CAMINHO DO ARQUIVO

path1 = 'gs://e-commerce-brazil/bases-originais-olist/olist_customers_dataset.csv' #Path do arquivo dentro da google storage
path2 = 'gs://e-commerce-brazil/bases-originais-olist/olist_geolocation_dataset.csv'
path3 = 'gs://e-commerce-brazil/bases-originais-olist/olist_order_items_dataset.csv' 
path4 = 'gs://e-commerce-brazil/bases-originais-olist/olist_order_payments_dataset.csv'
path5 = 'gs://e-commerce-brazil/bases-originais-olist/olist_order_reviews_dataset.csv'
path6 = 'gs://e-commerce-brazil/bases-originais-olist/olist_orders_dataset.csv'
path7 = 'gs://e-commerce-brazil/bases-originais-olist/olist_products_dataset.csv'
path8 = 'gs://e-commerce-brazil/bases-originais-olist/olist_sellers_dataset.csv'
path9 = 'gs://e-commerce-brazil/bases-originais-olist/product_category_name_translation.csv'

# %% [markdown]
# Session Spark

# %%
spark = (
    SparkSession.builder
                .master('local')
                .appName('gcsfs')
                .config('spark.ui.port', '4050')
                .config("spark.jars", 'https://storage.googleapis.com/hadoop-lib/gcs/gcs-connector-hadoop2-2.1.1.jar')
                .getOrCreate()
)

# %%
df1 = (
    spark.read.format('xlsx')
              .option('header', 'true')
              .option('inferschema', 'false')
              .option('delimiter', ',')
              .option('encoding', 'UTF-8')
              .load(path1)
)

# %% [markdown]
# # ETL with spark

# %% [markdown]
# Extração dos dados Spark

# %% [markdown]
# Read with spark

# %%
df1 = (
    spark.read.format('csv')
              .option('header', 'true')
              .option('inferschema', 'false')
              .option('delimiter', ',')
              .option('encoding', 'UTF-8')
              .load(path1)
)
df2 = (
    spark.read.format('csv')
              .option('header', 'true')
              .option('inferschema', 'false')
              .option('delimiter', ',')
              .option('encoding', 'UTF-8')
              .load(path2)
)
df3 = (
    spark.read.format('csv')
              .option('header', 'true')
              .option('inferschema', 'false')
              .option('delimiter', ',')
              .option('encoding', 'UTF-8')
              .load(path3)
)
df4 = (
    spark.read.format('csv')
              .option('header', 'true')
              .option('inferschema', 'false')
              .option('delimiter', ',')
              .option('encoding', 'UTF-8')
              .load(path4)
)
df5 = (
    spark.read.format('csv')
              .option('header', 'true')
              .option('inferschema', 'false')
              .option('delimiter', ',')
              .option('encoding', 'UTF-8')
              .load(path5)
)
df6 = (
    spark.read.format('csv')
              .option('header', 'true')
              .option('inferschema', 'false')
              .option('delimiter', ',')
              .option('encoding', 'UTF-8')
              .load(path6)
)
df7 = (
    spark.read.format('csv')
              .option('header', 'true')
              .option('inferschema', 'false')
              .option('delimiter', ',')
              .option('encoding', 'UTF-8')
              .load(path7)
)
df8 = (
    spark.read.format('csv')
              .option('header', 'true')
              .option('inferschema', 'false')
              .option('delimiter', ',')
              .option('encoding', 'UTF-8')
              .load(path8)
)
df9 = (
    spark.read.format('csv')
              .option('header', 'true')
              .option('inferschema', 'false')
              .option('delimiter', ',')
              .option('encoding', 'UTF-8')
              .load(path9)
)

# %%
df1.show(truncate=False)

# %%
df2.show(truncate=False)

# %%
df4.show(truncate=False)

# %%
df3.show(truncate=False)

# %% [markdown]
# Verificando df's
#
# df1 -valores: nullos, zortea
# valor número em campo errado(UF) ex: (99441)
#
# **df2** - óleo | TO, * cidade, valores null
#
# df3 - valores nulos, float misturado com int
#
# df4 - valores nulos, float misturado com int, int em campo de string(103886)
#
# df5 -  (70 + R$15), emoji em campo de int, string em campo de float, campos misturados com int, float e string
#
# df6 - campo data misturado com int e null, campo status misturados com int e null,
#
# df7 - campo data misturado com int e null, campo status misturados com int e null,
#
# df8 - campo data misturado com int e null, campo status misturados com int e null,
#
# df9 - campo data misturado com int e null, campo status misturados com int e null

# %%
#analisando os campos
df1.summary().show()

# %%
df2.summary().show()

# %%
df3.summary().show()

# %%
df4.summary().show()

# %%
df5.summary().show()

# %%
df6.summary().show()

# %%
df7.summary().show()

# %%
df8.summary().show()

# %%
df9.summary().show()

# %% [markdown]
# Verificando duplicatas

# %%
df1.dtypes
# Out:
# [('customer_id', 'string'),
#  ('customer_unique_id', 'string'),
#  ('customer_zip_code_prefix', 'string'),
#  ('customer_city', 'string'),
#  ('customer_state', 'string')]

# %%
#Verify duplicate values
df1 \
    .groupby(['id_cliente', 'unico_id_cliente','prefixo_codigo_postal_cliente','cidade_cliente','estado_cliente']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show()

# %%
df3.dtypes

# %%
#Verify duplicate values
df3 \
    .groupby(['order_id', 'order_item_id','product_id','seller_id','shipping_limit_date']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show()

# %%
df4.dtypes

# %%
df4 \
    .groupby(['id_pedido', 'pagamento_sequencial','tipo_de_pagamento']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show()

# %%
df5.dtypes

# %%
# valores duplicados, null, e em campo errado
df5  \
    .groupby(['id_pedido']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False)\
    .show()

# %%
df6.show()

# %%
#sem valores duplicados

df6 \
    .groupby(['order_id', 'customer_id','order_status']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False)\
    .show()

# %%
df7.dtypes

# %%
#sem valores duplicados

df7 \
    .groupby(['product_id']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False)\
    .show()

# %%
df8.dtypes

# %%
#sem valores duplicados
df8 \
    .groupby(['seller_id','seller_zip_code_prefix']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False)\
    .show()

# %%
df9.dtypes #não precisa verificar

# %% [markdown]
# # Tanslate columns

# %%
#RENOMENADO AS COLUNAS
df1= (df1
        .withColumnRenamed('customer_id','id_cliente')
        .withColumnRenamed('customer_unique_id','unico_id_cliente')
        .withColumnRenamed('customer_zip_code_prefix','prefixo_codigo_postal_cliente')
        .withColumnRenamed('customer_city','cidade_cliente')
        .withColumnRenamed('customer_state','estado_cliente')              
)

# %%
df2= (df2
        .withColumnRenamed('geolocation_zip_code_prefix','prefixo_codigo_postal_geolocalização')
        .withColumnRenamed('geolocation_lat','geolocalizacao_lat')
        .withColumnRenamed('geolocation_lng','geolocalizacao_lng')
        .withColumnRenamed('geolocation_city','geolocalizacao_cidade')
        .withColumnRenamed('geolocation_state','geolocalizacao_estado')             
)

# %%
df5= (df5
        .withColumnRenamed('review_id','id_comentario')
        .withColumnRenamed('order_id','id_pedido')
        .withColumnRenamed('review_score','pontuacao_avaliacao')
        .withColumnRenamed('review_comment_title','titulo_da_avaliacao')
        .withColumnRenamed('review_comment_message','mensagem_da_avaliacao')
        .withColumnRenamed('review_creation_date','data_criacao_avaliacao')
        .withColumnRenamed('review_answer_timestamp','data/hora_resposta_valiacao')            
)

# %%
df6= (df6
        .withColumnRenamed('order_id','id_pedido')
        .withColumnRenamed('customer_id','id_cliente')
        .withColumnRenamed('order_status','status_pedido')
        .withColumnRenamed('order_purchase_timestamp','data/hora_compra_pedido')
        .withColumnRenamed('order_approved_at','hora_aprovacao_pedido')
        .withColumnRenamed('order_delivered_carrier_date','data_entrega_pedido_para_transportadora')
        .withColumnRenamed('order_delivered_customer_date','data_entrega_pedido_ao_cliente')
        .withColumnRenamed('order_estimated_delivery_date','data_estimada_entrega_pedido')             
)

# %%
df7= (df7
        .withColumnRenamed('product_id','id_produto')
        .withColumnRenamed('product_category_name','nome_categoria_produto')
        .withColumnRenamed('product_name_lenght','tamanho_nome_produto')
        .withColumnRenamed('product_description_lenght','tamanho_descricao_produto')
        .withColumnRenamed('product_photos_qty','qtd_fotos_produto')
        .withColumnRenamed('product_weight_g','peso_produto_gramas')
        .withColumnRenamed('product_length_cm','comprimento_produto_cm')
        .withColumnRenamed('product_height_cm','altura_produto_cm')
        .withColumnRenamed('product_width_cm','largura_produto_cm')          
)

# %%
# RENOMEAR DF4
#RENOMEAR AS COLUNAS DF3
df3 = ( df3.withColumnRenamed('order_id','id_pedido')
          .withColumnRenamed('order_item_id','id_item_pedido')
          .withColumnRenamed('product_id','id_produto')
          .withColumnRenamed('seller_id','id_vendedor')
          .withColumnRenamed('acousticness','acustica')
          .withColumnRenamed('shipping_limit_date','data_limite_envio')
          .withColumnRenamed('energy','energia')
          .withColumnRenamed('price','preco')
          .withColumnRenamed('key','nota_musical')
          .withColumnRenamed('freight_value','valor_frete')                    
)

# %%
# RENOMEAR DF4
#RENOMEAR AS COLUNAS DF4
df4 = ( df4.withColumnRenamed('order_id','id_pedido')
          .withColumnRenamed('payment_sequential','pagamento_sequencial')
          .withColumnRenamed('payment_type','tipo_de_pagamento')
          .withColumnRenamed('payment_installments','pagamento_parcelas')
          .withColumnRenamed('payment_value','valor_pagamento')                                           
)

# %%
# RENOMEAR DF8
#RENOMEAR AS COLUNAS DF8
df8 = ( df8.withColumnRenamed('seller_id','id_vendedor')
          .withColumnRenamed('seller_zip_code_prefix','prefixo_cod_postal_vendedor')
          .withColumnRenamed('seller_city','vendedor_cidade')
          .withColumnRenamed('seller_state','vendedor_estado')
                                     
)

# %%
# RENOMEAR DF9
#RENOMEAR AS COLUNAS DF9
df9 = ( df9.withColumnRenamed('product_category_name','nome_cat_produto')
          .withColumnRenamed('product_category_name_english','nome_categoria_prod_ingles')                          
)

# %% [markdown]
# # Limpeza e dropagem

# %% [markdown]
# Limpeza do df1

# %%
backup_df1 = df1 #Backup do df1

# %%
df1.count()
# Out:
# 99441

# %%
#A
df1.summary().show(truncate=False)

# %%
df1 = df1.drop(F.col('unico_id_cliente')) 
df1 = df1.drop(F.col('prefixo_codigo_postal_cliente'))

# %%
#Limpeza da DF1 
df1 = (df1.withColumn('cidade_cliente', F.regexp_replace('cidade_cliente','zortea','')))

#df.select(regexp_replace('str', r'(\d+)', '--').alias('d')).collect()

# %%
df1.filter(F.col('estado_cliente') == 'TO').show()

# %%
#df1.select ('id_cliente').distinct().orderBy(F.col('id_cliente').asc()).show(truncate=False)


df1 \
    .groupby(['cidade_cliente']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show(truncate=False)


#df1.groupBy('estado_cliente').count().collect()

# %%
df1.filter(F.col('cidade_cliente') == 'pareci novo').show()

# %%
#Removendo os duplicados campo ID
df1.select(F.count('id_cliente')).show()
# Out:
# +-----------------+
# |count(id_cliente)|
# +-----------------+
# |            99441|
# +-----------------+

# %%
df1 = df1.dropDuplicates(['id_cliente'])

# %% [markdown]
# limpeza df2

# %%
df2_backup = df2

# %%
df2 = df2_backup

# %%
df2.dtypes
# Out:
# [('prefixo_codigo_postal_geolocalização', 'string'),
#  ('geolocalizacao_lat', 'string'),
#  ('geolocalizacao_lng', 'string'),
#  ('geolocalizacao_cidade', 'string'),
#  ('geolocalizacao_estado', 'string')]

# %%
df2 = df2.drop(F.col('prefixo_codigo_postal_geolocalização')) 
df2 = df2.drop(F.col('geolocalizacao_lat')) 
df2 = df2.drop(F.col('geolocalizacao_lng'))

# %%
# erros: ´ ( )
df2 \
    .groupby(['geolocalizacao_cidade','geolocalizacao_estado']) \
    .count() \
    .where('count == 1') \
    .sort('count', ascending=False) \
    .show(truncate=False)

# %%
df2 = (df2.withColumn('geolocalizacao_cidade', F.regexp_replace('geolocalizacao_cidade', '´', '')))

# %%
df2.groupBy('geolocalizacao_cidade','geolocalizacao_cidade').count().collect()

# %%
df2.summary().show(truncate=False)

# %% [markdown]
# df3 limpeza

# %%
df3_backup = df3

# %%
df3 = df3_backup

# %%
df3.summary().show(truncate=False)

# %%
#Valores duplicados
df3 \
    .groupby(['id_pedido']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show(truncate=False)

#df3.groupBy('id_produto','data_limite_envio','preco','valor_frete').count().collect()

# %%
#Removendo os duplicados campo ID
df3.select(F.count('id_pedido')).show()
# Out:
# +----------------+
# |count(id_pedido)|
# +----------------+
# |          112650|
# +----------------+

# %%
df3 = df3.dropDuplicates(['id_pedido'])

# %%
# Verify count column
df3.select(F.count('id_pedido')).show()
# Out:
# +----------------+
# |count(id_pedido)|
# +----------------+
# |           98666|
# +----------------+

# %%
df3.show(truncate=False)

# %%
df3 = ( \
        df3.drop(F.col('data_limite_envio'))\
        .drop(F.col('data_limite_envio'))
        )

# %%
df3.dtypes
# Out:
# [('id_pedido', 'string'),
#  ('id_item_pedido', 'string'),
#  ('id_produto', 'string'),
#  ('id_vendedor', 'string'),
#  ('preco', 'string'),
#  ('valor_frete', 'string')]

# %% [markdown]
# df4 limpeza

# %%
df4_backup = df4

# %%
df4.show(truncate=False)

# %%
df4.show()

# %%
df4 \
    .groupby(['pagamento_parcelas']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=True) \
    .show(truncate=False)

# %%
df4 \
    .groupby(['tipo_de_pagamento']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show(truncate=False)

# %%
#ID DO PEDIDO REPETINDO 
df4 \
    .groupby(['pagamento_sequencial']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show(truncate=False)

#df4.groupBy('pagamento_sequencial').count().collect()

# %%
#Removendo os duplicados campo ID
df4.select(F.count('id_pedido')).show()
# Out:
# +----------------+
# |count(id_pedido)|
# +----------------+
# |          103886|
# +----------------+

# %%
df4 = df4.dropDuplicates(['id_pedido'])

# %%
# Verify count column
df4.select(F.count('id_pedido')).show()

# %%
df4 = (df4.withColumn('tipo_de_pagamento', F.regexp_replace('tipo_de_pagamento','credit_card','cartao_credito')))
df4 = (df4.withColumn('tipo_de_pagamento', F.regexp_replace('tipo_de_pagamento','voucher','cupom')))
df4 = (df4.withColumn('tipo_de_pagamento', F.regexp_replace('tipo_de_pagamento','debit_card','cartao_debito')))

# %%
#Alterando valor Not defined por Não informado

df4 = df4.withColumn("tipo_de_pagamento", F.regexp_replace('tipo_de_pagamento','not_defined','nao_informado')) # <-- 
#df4 = df4.withColumn("tipo_de_pagamento", F.regexp_replace('tipo_de_pagamento','Não informado','nao_informado'))

# %%
df4 = df4.withColumn('valor_pagamento', F.col('valor_pagamento').cast(FloatType())) #Casting de dados str to int, float
df4 = df4.withColumn('pagamento_parcelas', F.col('pagamento_parcelas').cast(IntegerType()))
df4 = df4.withColumn('pagamento_sequencial', F.col('pagamento_sequencial').cast(IntegerType()))

# %%
df4.show()

# %%
df4.filter(F.col('pagamento_sequencial') == '5').show()

# %% [markdown]
# Limpeza df5
#
# Falta remover dados campo ID_PEDIDO

# %%
df5_backup = df5

# %%
df5 = df5_backup

# %%
df5.dtypes
# Out:
# [('id_comentario', 'string'),
#  ('id_pedido', 'string'),
#  ('pontuacao_avaliacao', 'string'),
#  ('titulo_da_avaliacao', 'string'),
#  ('mensagem_da_avaliacao', 'string'),
#  ('data_criacao_avaliacao', 'string'),
#  ('data/hora_resposta_valiacao', 'string')]

# %%
df5.summary().show(truncate=False)

# %%
df5 = ( \
        df5.drop(F.col('id_comentario'))\
        .drop(F.col('titulo_da_avaliacao'))
        .drop(F.col('mensagem_da_avaliacao'))
        .drop(F.col('data_criacao_avaliacao'))
        .drop(F.col('data/hora_resposta_valiacao'))
        )

# %%
# Chave id_pedido se reptindo dentro do dataframe 
df5 \
    .groupby(['id_pedido']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show(truncate=False)

#df4.groupBy('pagamento_sequencial').count().collect()

# %%
#Removendo os duplicados campo ID
df5.select(F.count('id_pedido')).show()
# Out:
# +----------------+
# |count(id_pedido)|
# +----------------+
# |          101926|
# +----------------+

# %%
df5 = df5.dropDuplicates(['id_pedido'])

# %%
# Verify count column
df5.select(F.count('id_pedido')).show()
# Out:
# +----------------+
# |count(id_pedido)|
# +----------------+
# |           99742|
# +----------------+

# %%
df5 \
    .groupby(['id_pedido']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show(truncate=False)
# Out:
# +-------------------+-----+
# |id_pedido          |count|
# +-------------------+-----+
# |null               |2236 |
# |2018-05-15 00:00:00|16   |
# |2017-12-19 00:00:00|16   |
# |2017-12-16 00:00:00|15   |
# |2018-02-24 00:00:00|15   |
# |2018-04-11 00:00:00|14   |
# |2018-08-18 00:00:00|14   |
# |2017-12-06 00:00:00|14   |
# |2018-08-28 00:00:00|13   |
# |2018-08-17 00:00:00|12   |
# |2018-03-30 00:00:00|12   |
# |2018-06-21 00:00:00|11   |
# |2018-04-13 00:00:00|11   |
# |2018-01-27 00:00:00|11   |
# |2018-03-21 00:00:00|11   |
# |2018-08-10 00:00:00|11   |
# |2018-08-04 00:00:00|11   |
# |2017-12-13 00:00:00|11   |
# |2018-03-02 00:00:00|11   |
# |2018-05-23 00:00:00|11   |
# +-------------------+-----+
# only showing top 20 rows

# %% [markdown]
# Removendo erros no campo ID: "2018", "2017", " "

# %%
#Esse o verdeiro heroi
df5 = df5.withColumn("id_pedido",F.when(F.col("id_pedido").rlike("2018"),F.lit("nao_informado")).otherwise(F.col("id_pedido")))
df5 = df5.withColumn("id_pedido",F.when(F.col("id_pedido").rlike("2017"),F.lit("nao_informado")).otherwise(F.col("id_pedido")))

# %%
df5 = df5.withColumn("id_pedido",F.when(F.col("id_pedido").rlike(" "),F.lit("nao_informado")).otherwise(F.col("id_pedido")))

# %%
df5 = df5.withColumn("id_pedido",F.when(F.col("id_pedido").rlike(" "),F.lit("nao_informado")).otherwise(F.col("id_pedido")))

# %%
df5.filter(F.col('pontuacao_avaliacao') == '5.0').show()

# %%
#Verificando col pontuacao_avaliacao
df5 \
    .groupby(['pontuacao_avaliacao']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show(truncate=False)

# %%
#limpando col pontuacao_avaliacao
df5 = df5.withColumn("pontuacao_avaliacao",F.when(F.col("id_pedido").rlike("2018"),F.lit("nao_informado")).otherwise(F.col("id_pedido")))
df5 = df5.withColumn("pontuacao_avaliacao",F.when(F.col("id_pedido").rlike("2017"),F.lit("nao_informado")).otherwise(F.col("id_pedido")))

# %% [markdown]
# limpeza df6

# %%
df6_backup = df6

# %%
df6 = df6_backup

# %%
df6.dtypes
# Out:
# [('id_pedido', 'string'),
#  ('id_cliente', 'string'),
#  ('status_pedido', 'string'),
#  ('data/hora_compra_pedido', 'string'),
#  ('hora_aprovacao_pedido', 'string'),
#  ('data_entrega_pedido_para_transportadora', 'string'),
#  ('data_entrega_pedido_ao_cliente', 'string'),
#  ('data_estimada_entrega_pedido', 'string')]

# %%
#Analisando coluna id_item_pedido: Dropar?
df6.filter(F.col('id_item_pedido') == '1').show()

# %%
df6.dtypes
# Out:
# [('id_pedido', 'string'),
#  ('id_cliente', 'string'),
#  ('status_pedido', 'string'),
#  ('data/hora_compra_pedido', 'string'),
#  ('data_entrega_pedido_ao_cliente', 'string'),
#  ('data_estimada_entrega_pedido', 'string')]

# %%
# duplicates value
df6 \
    .groupby(['id_pedido']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show(truncate=False)

# %%
#Removendo os duplicados campo ID
df6.select(F.count('id_pedido')).show()
# Out:
# +----------------+
# |count(id_pedido)|
# +----------------+
# |           99441|
# +----------------+

# %%
df6 = df6.dropDuplicates(['id_pedido'])

# %%
# Verify count column
df6.select(F.count('id_pedido')).show()
# Out:
# +----------------+
# |count(id_pedido)|
# +----------------+
# |           99441|
# +----------------+

# %%
# Limpo
df6 \
    .groupby(['id_item_pedido']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show(truncate=False)

# %%
df6 = (df6.drop(F.col('id_item_pedido'))) #Drop col: id_item_pedido

# %%
#Valores estao corretos
df6 \
    .groupby(['valor_frete']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show(truncate=False)

# %%
df6.summary().show(truncate=False)

# %%
df6.dtypes

# %%
#Dropagem colunas 
df6 = ( \
        df6.drop(F.col('hora_aprovacao_pedido'))\
        .drop(F.col('data_entrega_pedido_para_transportadora'))
        )

# %% [markdown]
# Convert columns with casting datetime

# %%
#Verificar colunas

# %% [markdown]
# Limpeza df7

# %%
df7_backup = df7

# %%
df7.dtypes
# Out:
# [('id_produto', 'string'), ('peso_produto_gramas', 'string')]

# %%
df7.show()

# %%
#Dropagem colunas 
df7 = ( \
        df7.drop(F.col('nome_categoria_produto'))\
        .drop(F.col('tamanho_nome_produto')) \
        .drop(F.col('tamanho_descricao_produto')) \
       .drop(F.col('qtd_fotos_produto')) \
       .drop(F.col('altura_produto_cm')) \
       .drop(F.col('largura_produto_cm'))
       .drop(F.col('comprimento_produto_cm'))  
)

# %%
#Casting data
df7 = df7.withColumn('peso_produto_gramas', F.col('peso_produto_gramas').cast(FloatType()))
#df7 = df7.withColumn('largura_produto_cm', F.col('comprimento_produto_cm').cast(IntegerType()))

# %%
#Dados estão limpos? Maybe
df7 \
    .groupby(['id_produto']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=True) \
    .show(truncate=False)

# %%
#Dados estão limpos | Verificar conversão int para float e info da coluna peso_produto_gramas
df7 \
    .groupby(['peso_produto_gramas']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show(truncate=False)

# %% [markdown]
# df8 limpeza

# %%
df8_backup = df8

# %%
df8 = df8_backup

# %%
df8.show()

# %%
df8.dtypes
# Out:
# [('vendedor_id', 'string'),
#  ('vendedor_cidade', 'string'),
#  ('vendedor_estado', 'string')]

# %%
#Dropar col prefixo_cod_postal_vendedor
df8 = (df8.drop(F.col('prefixo_cod_postal_vendedor')))

# %%
# rio de janeiro, rio de janeiro, brasil || 4482255.0 valores float e int dentro da coluna 
df8 \
    .groupby(['vendedor_cidade']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show(truncate=False)

# %%
#Limpo os dados com regex
df8 = (df8.withColumn('vendedor_cidade', F.regexp_replace('vendedor_cidade','rio de janeiro, rio de janeiro, brasil','rio de janeiro')))

# %%
df8 = df8.withColumn("vendedor_cidade",F.when(F.col("vendedor_cidade").rlike("44"),F.lit("nao_informado")).otherwise(F.col("vendedor_cidade")))

# %%
#dados limpos 
df8 \
    .groupby(['vendedor_estado']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show(truncate=False)

# %%
#
df8 \
    .groupby(['vendedor_id']) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show(truncate=False)

# %%
df8.summary().show(truncate=False)

# %%
#
#maua/sao paulo || rio de janeiro \\rio de janeiro || santa barbara d´oeste | 04482255 || /sp -> Valores encontrados na analise
df8.groupBy('vendedor_cidade').count().collect()

# %%
#Limpo os dados com regex
df8 = (df8.withColumn('vendedor_cidade', F.regexp_replace('vendedor_cidade','/',' ')))
df8 = (df8.withColumn('vendedor_cidade', F.regexp_replace('vendedor_cidade','sp','sao paulo')))
df8 = (df8.withColumn('vendedor_cidade', F.regexp_replace('vendedor_cidade','vendas@creditparts.com.br','nao_informado')))

# %%
df8 = df8.withColumn("vendedor_cidade",F.when(F.col("vendedor_cidade").rlike(""),F.lit("nao_informado")).otherwise(F.col("vendedor_cidade")))

# %%
df8.filter(F.col('vendedor_cidade') == '´').show()

# %% [markdown]
# # Agrupando os DF'S

# %%
'''
df1 > df6 : id_cliente
df3 > df8 : id_vendedor
df4 > df5 : id_pedido

'''

# %%
df4.dtypes

# %%
df5.dtypes
# Out:
# [('id_pedido', 'string'), ('pontuacao_avaliacao', 'string')]

# %%
df_final.dtypes
# Out:
# [('id_cliente', 'string'),
#  ('cidade_cliente', 'string'),
#  ('estado_cliente', 'string'),
#  ('id_pedido', 'string'),
#  ('status_pedido', 'string'),
#  ('data/hora_compra_pedido', 'string'),
#  ('data_entrega_pedido_ao_cliente', 'string'),
#  ('data_estimada_entrega_pedido', 'string')]

# %%
df_final2.dtypes
# Out:
# [('id_vendedor', 'string'),
#  ('id_pedido', 'string'),
#  ('preco', 'string'),
#  ('valor_frete', 'string'),
#  ('vendedor_cidade', 'string'),
#  ('vendedor_estado', 'string')]

# %%
df_final3.dtypes
# Out:
# [('id_pedido', 'string'),
#  ('pagamento_sequencial', 'int'),
#  ('tipo_de_pagamento', 'string'),
#  ('pagamento_parcelas', 'int'),
#  ('valor_pagamento', 'float'),
#  ('pontuacao_avaliacao', 'string')]

# %%
#Dropando colunas que não vamos utilizar no df3
df3 = df3.drop(F.col('id_item_pedido')) 
df3 = df3.drop(F.col('id_produto'))

# %%
# df1 > df6 : id_cliente
df_final = df1.join(df6, on = ['id_cliente'], how = 'inner')

# %%
# df3 > df8 : id_vendedor
df_final2 = df3.join(df8, on = ['id_vendedor'], how = 'inner')

# %%
# df4 > df5 : id_pedido
df_final3 = df4.join(df5, on =['id_pedido'], how = 'inner')

# %%
#Usando df_final4 para agrupar todos os 3 dataframes finais ao dataframe da olist completo
df_final4 = df_final.join(df_final2, on=['id_pedido'])

# %%
# recebendo todos os dados em dataframe "DF_OLIST"
df_olist = df_final4.join(df_final3, on=['id_pedido'], how = 'inner')

# %%
#Verificando dataframe final
df_olist.dtypes

# %%
df_olist.count()
# Out:
# 97824

# %% [markdown]
# ID_pedido
# ID_produto

# %% [markdown]
# iniciando plotagem

# %%
# Converta o dataframe do PySpark para o Pandas
#df_olist_pd = df_final.toPandas()

df_olist_pd = df_olist.toPandas()
# Exiba o dataframe do Pandas
df_olist_pd.head(5)

# %% [markdown]
# # Analisando com pandas

# %%
df_olist_pd.dtypes

# %%
df_olist_pd.tail()

# %%
#Dropandando coluna id_item_pedido
df_olist_pd.drop(['id_item_pedido'],axis=1,inplace=True)

# %%
#FUNÇÃO PARA REMOVER ESPAÇOS EM BRANCO

def whitespace_remover(dataframe):
    # percorrendo cada coluna
    for i in dataframe.columns:
        # checando o tipo de cada coluna
        if dataframe[i].dtype == 'object': 
            # aplicando o metodo strip
            dataframe[i] = dataframe[i].map(str.strip)
        else:
            # caso coluna diferente de object não fazer nada.
            pass

whitespace_remover(df_olist_pd)

# %%
#Verificando valores nulos
df_olist_pd.isna().sum()
# Out:
# id_pedido                            0
# id_cliente                           0
# cidade_cliente                       0
# estado_cliente                       0
# status_pedido                        0
# data/hora_compra_pedido              0
# data_entrega_pedido_ao_cliente    2085
# data_estimada_entrega_pedido         0
# id_vendedor                          0
# preco                                0
# valor_frete                          0
# vendedor_cidade                      0
# vendedor_estado                      0
# pagamento_sequencial                 0
# tipo_de_pagamento                    0
# pagamento_parcelas                   0
# valor_pagamento                      0
# pontuacao_avaliacao                  0
# dtype: int64

# %%
#Plotagem grárfico de barra
df_olist_pd.groupby(['estado_cliente'],dropna=False).size().sort_values(ascending=False).head(5).plot.bar(figsize=(12,8),xlabel='ESTADO',ylabel='Qtd. Ocorrencias')

# %%
#Plotagem grárfico de barra
df_olist_pd.groupby(['tipo_de_pagamento'],dropna=False).size().sort_values(ascending=False).head(5).plot.bar(figsize=(12,8),xlabel='Pagamento',ylabel='Qtd. Pagamento')

# %%
#Plotagem grárfico de barra
df_olist_pd.groupby(['status_pedido'],dropna=False).size().sort_values(ascending=False).plot.line()
#df_olist_pd.groupby(['data/hora_compra_pedido'],dropna=False).size().sort_values(ascending=False).head(5).plot.bar(figsize=(12,8),xlabel='Pagamento',ylabel='Qtd. Pagamento')

# %%
#Casting de dados datatime
df_olist_pd["data_entrega_pedido_ao_cliente"] = df_olist_pd["data_entrega_pedido_ao_cliente"].astype('str')

# %%
#Casting de dados datatime
df_olist_pd["data_estimada_entrega_pedido"] = df_olist_pd["data_estimada_entrega_pedido"].astype('str')

# %%
#Casting de dados datatime
df_olist_pd["data/hora_compra_pedido"] = df_olist_pd["data/hora_compra_pedido"].astype('str')

# %%
df_olist_pd.dtypes

# %% [markdown]
# Tratar dados nulos coluna datetime e colunas repetidas:
#
# 1.  pagamento_parcela;
# 2.  valor_pagamento;
# 3.  tipo_pagamento;
# 4.  pagamento_sequencial;

# %%
#Verificando valores nulos
df_olist_pd.isna().sum()
# Out:
# id_pedido                         0
# id_cliente                        0
# cidade_cliente                    0
# estado_cliente                    0
# status_pedido                     0
# data/hora_compra_pedido           0
# data_entrega_pedido_ao_cliente    0
# data_estimada_entrega_pedido      0
# id_item_pedido                    0
# id_produto                        0
# id_vendedor                       0
# preco                             0
# valor_frete                       0
# pagamento_sequencial              0
# tipo_de_pagamento                 0
# pagamento_parcelas                0
# valor_pagamento                   0
# dtype: int64

# %%
df_olist_pd.dtypes
# Out:
# id_pedido                                 object
# id_cliente                                object
# cidade_cliente                            object
# estado_cliente                            object
# status_pedido                             object
# data/hora_compra_pedido           datetime64[ns]
# data_entrega_pedido_ao_cliente    datetime64[ns]
# data_estimada_entrega_pedido      datetime64[ns]
# id_vendedor                               object
# preco                                     object
# valor_frete                               object
# vendedor_cidade                           object
# vendedor_estado                           object
# pagamento_sequencial                      object
# tipo_de_pagamento                         object
# pagamento_parcelas                        object
# valor_pagamento                           object
# dtype: object

# %%
#Removendo colunas duplicadas via pandas
df_olist_pd = df_olist_pd.T.drop_duplicates().T

# %%
df_olist_pd = df_olist_pd.dropna(axis=0)

# %%
df_olist_pd.head()

# %% [markdown]
# Casting de dados

# %%
df_olist_pd.dtypes
# Out:
# id_pedido                                 object
# id_cliente                                object
# cidade_cliente                            object
# estado_cliente                            object
# status_pedido                             object
# data/hora_compra_pedido           datetime64[ns]
# data_entrega_pedido_ao_cliente    datetime64[ns]
# data_estimada_entrega_pedido      datetime64[ns]
# id_vendedor                               object
# preco                                    float64
# valor_frete                              float64
# vendedor_cidade                           object
# vendedor_estado                           object
# pagamento_sequencial                       int64
# tipo_de_pagamento                         object
# pagamento_parcelas                         int64
# valor_pagamento                          float64
# dtype: object

# %%
df_olist_pd["valor_pagamento"] = df_olist_pd["valor_pagamento"].astype('float')

# %%
df_olist_pd["preco"] = df_olist_pd["preco"].astype('float')

# %%
df_olist_pd["valor_frete"] = df_olist_pd["valor_frete"].astype('float')

# %%
df_olist_pd["pagamento_parcelas"] = df_olist_pd["pagamento_parcelas"].astype('int')

# %%
df_olist_pd["pagamento_sequencial"] = df_olist_pd["pagamento_sequencial"].astype('int')

# %%
df_olist_pd.head()
# Out:
#                           id_pedido                        id_cliente  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  3ce436f183e68e07877b285a838db11a
# 1  00018f77f2f0320c557190d7a144bdd3  f6dd3ec061db4e3987629fe6b26e5cce
# 2  000229ec398224ef6ca0657da4fc703e  6489ae5e4333f3693df5ad4372dab6d3
# 3  00024acbcdf0a6daa1e931b038114c75  d4eb9395c8c0431ee92fce09860c5a06
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  58dbd0b2d70206bf40e62cd34e84d795
#
#           cidade_cliente estado_cliente status_pedido data/hora_compra_pedido  \
# 0  campos dos goytacazes             RJ     delivered     2017-09-13 08:59:02
# 1        santa fe do sul             SP     delivered     2017-04-26 10:53:06
# 2          para de minas             MG     delivered     2018-01-14 14:33:31
# 3                atibaia             SP     delivered     2018-08-08 10:00:35
# 4        varzea paulista             SP     delivered     2017-02-04 13:57:51
#
#   data_entrega_pedido_ao_cliente data_estimada_entrega_pedido  \
# ...

# %%
# Arredonda os valores da coluna 'valores' para duas casas decimais
df_olist_pd['valor_pagamento'] = df_olist_pd['valor_pagamento'].round(2)

# %%
df_olist_pd.shape
# Out:
# (97824, 17)

# %% [markdown]
# # Conector Mongo

# %%
import pymongo
from pymongo import MongoClient

# %%
#from pymongo import MongoClient
uri = "mongodb+srv://cluster-proj-final.xqtocib.mongodb.net/?authSource=%24external&authMechanism=MONGODB-X509&retryWrites=true&w=majority"
client = MongoClient(uri,
                     tls=True,
                     tlsCertificateKeyFile='/content/X509-cert-5133275960310323922.pem')

# %%
dbt = client['tratado']
colecaot = dbt['base_tratada']

# %%
doc_count = colecaot.count_documents({})
print(doc_count)
# Out:
# 0

# %%
# inserção do DF pandas com o dataframe tratado, para o mongoDB, em foma de dicionário, 
# assim como foi feito o upload dos dataframes com os dados originais
# o DF estava grande demais para ser enviado para o Mongo então será enviado em pedaços ("chunks")
chunk_size = 1000
# definido o tamanho do chunk, calcula-se a quantidade de chunks
num_chunks = df_olist_pd.shape[0] // chunk_size + 1

# depois itera sobre os chunks
for i in range(num_chunks):
    # e cria um .loc em cima dele
    chunk = df_olist_pd.loc[i*chunk_size:(i+1)*chunk_size-1]

    # aqui converte-se cada chunk para uma lista de dicionários
    chunk_dict = chunk.to_dict('records')

    # e aqui eles são inseridos no MongoDB
    colecaot.insert_many(chunk_dict)

# %%
#montar o banco de dados para a base tratada 
db = client['BaseTratada']

# %%
#criando a coleção para a base tratada
col_df_olist = db['olist_2016_2018_tratado']
col_df_olist.count_documents({})
# Out:
# 0

# %% [markdown]
# # Enviando o dataset tratado para nosso datalake

# %%
#Gerando arquivo csv e fazendo o upload para GSC
df_olist_pd.to_csv('olsit_final_tratado',index=False)

# %%
df_olist_pd.head(10)
